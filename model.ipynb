# %% [markdown]
# # Behavioural Cloning Network
# ##### This notebook contains code to drive a car autonomously through the Udacity Car Simulator

# %%
import csv 
validation_samples = []
with open('./udacity_data/driving_log.csv') as csvfile:
    next(csvfile)
    reader = csv.reader(csvfile)
    for line in reader: 
        validation_samples.append(line)

train_samples = []
with open('./train_data/driving_log.csv') as csvfile:
    next(csvfile)
    reader = csv.reader(csvfile)
    for line in reader: 
        train_samples.append(line)        

with open('./train_data1/driving_log.csv') as csvfile:
    next(csvfile)
    reader = csv.reader(csvfile)
    for line in reader: 
        train_samples.append(line)

with open('./train_data2/driving_log.csv') as csvfile:
    next(csvfile)
    reader = csv.reader(csvfile)
    for line in reader: 
        train_samples.append(line) 

print(len(train_samples))
# Out:
# 14882

# %%
#image preprocessing steps 
import cv2 
import numpy as np  
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import os
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.data_utils import Sequence
import threading
import multiprocessing 
from keras.backend import tf as ktf 
import matplotlib.pyplot as plt
# %matplotlib inline
LEFT = 1
RIGHT = 2
CORRECTION_FACTOR = 0.25
LOWER_H = 60 
UPPER_H = 140
def change_brightness(image):
    """ function to randomly vary brightness, returns image in HSV color space """
    
    # Randomly select a percent change
    change_pct = np.random.uniform(0.5, 1.2)
    # Change to HSV to change the brightness V
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hsv[:,:,2] = hsv[:,:,2] * change_pct
    return hsv

def flip_image(image, angle):
    """ function to randomly flip images and reverse steering angles """
    
    img_flip = cv2.flip(image,1)
    angle = -angle
    return img_flip, angle

def trans_image(image,steer,trans_range):
    """ function to randomly translate images and compensate steering angles """
    
    # Translation
    tr_x = trans_range*np.random.uniform()-trans_range/2
    steer_ang = steer + tr_x/trans_range*2*.2 
    tr_y = 0
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])
    image_tr = cv2.warpAffine(image,Trans_M,(image.shape[1],image.shape[0]))
    
    return image_tr,steer_ang
    
def preprocess_image(image, angle): 
    """ function to perform random image preprocessing """
    
    image = change_brightness(image)
    image, angle = trans_image(image,angle,100)
    if np.random.randint(2) == 1:
        image, angle = flip_image(image, angle)
    return image, angle

class TrainingSequence(Sequence):
    def __init__(self, x_set, y_set, dirs, batch_size):
        self.X,self.y = x_set,y_set
        self.batch_size = batch_size
        self.dirs = dirs
        
    def __len__(self):
        return len(self.X) 

    def __getitem__(self,idx):
        idx %= ((len(self.X) / self.batch_size))
        idx = int(idx)
        batch_samples = self.X[idx*self.batch_size:(idx+1)*self.batch_size]    
        images = []
        angles = []
        for batch_sample in batch_samples:
            index = 0 
            rand_i = np.random.randint(low=0,high=3)
            path = './'+ self.dirs[index] + '/IMG/'+batch_sample[rand_i].split('/')[-1]                 
            image = cv2.imread(path)
            while image is None: 
                index += 1
                path = './'+ self.dirs[index] +'/IMG/'+batch_sample[rand_i].split('/')[-1] 
                image = cv2.imread(path)
            angle = float(batch_sample[3])
            if rand_i == LEFT: 
                angle += CORRECTION_FACTOR 
            elif rand_i == RIGHT: 
                angle -= CORRECTION_FACTOR
            image, angle = preprocess_image(image, angle) 
            images.append(image[LOWER_H:UPPER_H,:])
            angles.append(angle)
        X_train = np.array(images)
        y_train = np.array(angles)
        return X_train, y_train

class ValidationSequence(Sequence):
    def __init__(self, x_set, y_set, dirs, batch_size):
        self.X,self.y = x_set,y_set
        self.batch_size = batch_size
        self.dirs = dirs
        
    def __len__(self):
        return len(self.X) 

    def __getitem__(self,idx):
        idx %= ((len(self.X) / self.batch_size))
        idx = int(idx)
        batch_samples = self.X[idx*self.batch_size:(idx+1)*self.batch_size]    
        images = []
        angles = []
        for batch_sample in batch_samples:
            index = 0 
            rand_i = np.random.randint(low=0,high=3)
            path = './'+ self.dirs[index] + '/IMG/'+batch_sample[rand_i].split('/')[-1]                 
            image = cv2.imread(path)
            while image is None: 
                index += 1
                path = './'+ self.dirs[index] +'/IMG/'+batch_sample[rand_i].split('/')[-1] 
                image = cv2.imread(path)
            angle = float(batch_sample[3])
            image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
            images.append(image[LOWER_H:UPPER_H,:])
            angles.append(angle)
        X_train = np.array(images)
        y_train = np.array(angles)
        return X_train, y_train

def make_histogram(sequence):
    """ function to display a histogram given a sequence object """
    
    bins = np.arange(-1,1, 0.05)  
    x_data = [] 
    y_data = []
    for i in range(int(sequence.__len__() / 256)):
        x_batch, y_batch = sequence.__getitem__(i)
        x_data.append(x_batch)
        y_data.append(y_batch)
    
    fig, ax = plt.subplots(ncols=1, figsize=(20, 10), linewidth=1)
    # Create a histogram by providing the bin edges (unequally spaced).
    ax.hist(y_data, bins, histtype='stepfilled', facecolor='y')
    ax.set_title('Validation Set Distribution')  
    fig.tight_layout()
    plt.show()

def display_images(sequence , num_to_display): 
    """ function to display a 20 images from a sequence, used for exploratory data analysis """
    
    plt.rcParams["figure.figsize"] = [20, num_to_display]
    batch_x, batch_y = sequence.__getitem__(1)
    for i in range(0, num_to_display):
        print(batch_x[i].shape)
        plt.subplot(4, 5, i+1) 
        plt.tight_layout()
        plt.axis('off')
        plt.title(str(np.round(batch_y[i],5)), fontsize=30)
        plt.imshow(batch_x[i])

# %% [markdown]
# ##### This cell implements the neural network defined in the End to End Learning for Self-Driving Cars Nvidia Research Paper

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename= "./img/nvidia_net.png", width=500, height=80)

# %%
from keras.models import Sequential 
from keras.layers import Flatten, Dense, Lambda, Conv2D, Dropout
from keras.backend import tf as ktf 

def resize_normalize(image):
    import cv2
    from keras.backend import tf as ktf   
    
    # resize to (66, 20) as reccommended
    # in the nvidia paper for this used CNN
    resized = ktf.image.resize_images(image, (66, 200))
    #normalize 0-1
    resized = resized/255.0 - 0.5
    return resized

#resizing and normalization lambda layers
resize_normalize = Lambda(resize_normalize, input_shape=(80, 320, 3))

model = Sequential() 

model.add(resize_normalize)

# input: 3@66x200 conv ouput: 24@31x98
model.add(Conv2D(24, kernel_size=(5,5), strides=(2, 2), padding='valid', activation='elu', kernel_initializer='he_normal', bias_initializer='zeros'))
model.add(Dropout(0.2))
# conv output: 36@14x47
model.add(Conv2D(36, kernel_size=(5,5), strides=(2, 2), padding='valid', activation='elu', kernel_initializer='he_normal', bias_initializer='zeros'))          
model.add(Dropout(0.2))
# conv output: 48@5x22
model.add(Conv2D(48, kernel_size=(5,5), strides=(2, 2), padding='valid', activation='elu', kernel_initializer='he_normal', bias_initializer='zeros'))    

model.add(Dropout(0.2))
# conv output: 64@3x20
model.add(Conv2D(64, kernel_size=(3,3), strides=(1, 1), padding='valid', activation='elu', kernel_initializer='he_normal', bias_initializer='zeros')) 
model.add(Dropout(0.2))

# conv output: 64@1x18 
model.add(Conv2D(64, kernel_size=(3,3), strides=(1, 1), padding='valid', activation='elu', kernel_initializer='he_normal', bias_initializer='zeros')) 
model.add(Dropout(0.2))

# Fully connected layers
model.add(Flatten())
model.add(Dense(100, kernel_initializer='he_normal', bias_initializer='zeros', activation='elu'))
model.add(Dropout(0.2))
model.add(Dense(50, kernel_initializer='he_normal', bias_initializer='zeros', activation='elu')) 
model.add(Dropout(0.2))
model.add(Dense(10, kernel_initializer='he_normal', bias_initializer='zeros', activation='elu'))
model.add(Dropout(0.2))
model.add(Dense(1, kernel_initializer='he_normal', bias_initializer='zeros'))

model.compile(loss='mse', optimizer='adam')
print()

# %%
import keras
from keras.callbacks import EarlyStopping
import math
print(keras.__version__)
batch_size = 256

# Udacity validation data used for training as that yielded more consistent performance during testing
# compile and train the model using sequence objects for multiprocessing
print(math.ceil(len(train_samples)/batch_size))
print(math.ceil(len(validation_samples)/batch_size))
train_generator = TrainingSequence(validation_samples,None, ['udacity_data'], batch_size=batch_size)
validation_generator = ValidationSequence(train_samples,None, ['train_data', 'train_data1', 'train_data2' ], batch_size=batch_size)
#make_histogram(train_generator)
display_images(train_generator, 10)
#earlyStopping=keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, verbose=0, mode='min')
#make_histogram(validation_generator)
history_object = model.fit_generator(train_generator, validation_data=validation_generator, validation_steps=len(train_samples)/batch_size , epochs=20, steps_per_epoch=len(validation_samples)/batch_size , workers=4, use_multiprocessing=True, max_queue_size=2 )#, callbacks=[earlyStopping])
model.save('model.h5')

#./udacity_data/IMG/center_2016_12_01_13_30_48_287.jpg
# Out:
# 2.0.6
# 59
# 32
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# (80, 320, 3)
# Epoch 1/20
# 32/31 [==============================] - 21s - loss: 0.0876 - val_loss: 0.0157
# Epoch 2/20
# 32/31 [==============================] - 20s - loss: 0.0812 - val_loss: 0.0148
# Epoch 3/20
# 32/31 [==============================] - 20s - loss: 0.0790 - val_loss: 0.0225
# Epoch 4/20
# 32/31 [==============================] - 20s - loss: 0.0737 - val_loss: 0.0184
# Epoch 5/20
# 32/31 [==============================] - 19s - loss: 0.0689 - val_loss: 0.0198
# Epoch 6/20
# 32/31 [==============================] - 19s - loss: 0.0674 - val_loss: 0.0228
# Epoch 7/20
# 32/31 [==============================] - 20s - loss: 0.0666 - val_loss: 0.0208
# Epoch 8/20
# 32/31 [==============================] - 20s - loss: 0.0610 - val_loss: 0.0183
# Epoch 9/20
# 32/31 [==============================] - 20s - loss: 0.0607 - val_loss: 0.0256
# Epoch 10/20
# 32/31 [==============================] - 20s - loss: 0.0560 - val_loss: 0.0217
# Epoch 11/20
# 32/31 [==============================] - 20s - loss: 0.0562 - val_loss: 0.0206
# Epoch 12/20
# 32/31 [==============================] - 20s - loss: 0.0527 - val_loss: 0.0245
# Epoch 13/20
# 32/31 [==============================] - 19s - loss: 0.0536 - val_loss: 0.0249
# Epoch 14/20
# 32/31 [==============================] - 19s - loss: 0.0536 - val_loss: 0.0227
# Epoch 15/20
# 32/31 [==============================] - 20s - loss: 0.0515 - val_loss: 0.0254
# Epoch 16/20
# 32/31 [==============================] - 20s - loss: 0.0491 - val_loss: 0.0289
# Epoch 17/20
# 32/31 [==============================] - 20s - loss: 0.0483 - val_loss: 0.0258
# Epoch 18/20
# 32/31 [==============================] - 20s - loss: 0.0472 - val_loss: 0.0251
# Epoch 19/20
# 32/31 [==============================] - 19s - loss: 0.0459 - val_loss: 0.0373
# Epoch 20/20
# 32/31 [==============================] - 20s - loss: 0.0460 - val_loss: 0.0339

# %% [markdown]
# ##### This cell contains some training and validation statistics

# %%
from keras.models import Model
print(history_object.history.keys())
plt.plot(history_object.history['loss'])
plt.plot(history_object.history['val_loss'])
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['val_loss', 'loss'])
